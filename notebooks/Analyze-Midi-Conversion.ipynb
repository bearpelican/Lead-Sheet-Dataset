# %%
import json
from pathlib import Path
import music21

# %%
song_list = Path.cwd()/'../datasets/pianoroll'

# %%
midi_list = list(song_list.glob('*/wolfgang-gartner/*/*_original.mid')); midi_list
# Out:
# [PosixPath('/home/ubuntu/Lead-Sheet-Dataset/notebooks/../datasets/pianoroll/w/wolfgang-gartner/undertaker/intro_key_original.mid'),
#  PosixPath('/home/ubuntu/Lead-Sheet-Dataset/notebooks/../datasets/pianoroll/w/wolfgang-gartner/fire-power/pre-chorus_key_original.mid'),
#  PosixPath('/home/ubuntu/Lead-Sheet-Dataset/notebooks/../datasets/pianoroll/w/wolfgang-gartner/the-way-it-was/intro_key_original.mid'),
#  PosixPath('/home/ubuntu/Lead-Sheet-Dataset/notebooks/../datasets/pianoroll/w/wolfgang-gartner/space-junk/pre-chorus_key_original.mid'),
#  PosixPath('/home/ubuntu/Lead-Sheet-Dataset/notebooks/../datasets/pianoroll/w/wolfgang-gartner/love-and-war/verse_key_original.mid'),
#  PosixPath('/home/ubuntu/Lead-Sheet-Dataset/notebooks/../datasets/pianoroll/w/wolfgang-gartner/illmerica/verse_key_original.mid')]

# %%
# with open(midi_list[0], 'r') as f:
#     j = json.load(f)

# %%
fp = midi_list[0]; fp
# Out:
# PosixPath('/home/ubuntu/Lead-Sheet-Dataset/notebooks/../datasets/pianoroll/w/wolfgang-gartner/undertaker/intro_key_original.mid')

# %%
stream =  music21.converter.parse(fp)

# %%
stream.show()

# %%
stream.show()

# %%
ht_midi_list = list((ht_path/'pianoroll').glob('*/*/*/*_key_cmajor.mid'));

# %%
song_json = json.load(open(song_list, 'r'))

# %%
len(song_json)
# Out:
# 19922

# %%
list(Path('../datasets').glob('*)'))
# Out:
# []

# %%
j
# Out:
# {'version': None,
#  'metadata': {'title': 'undertaker',
#   'beats_in_measure': '4',
#   'BPM': '240',
#   'key': 'B',
#   'YouTubeID': 'JDt-iPEVZ4Q',
#   'mode': '6',
#   'duration': '9.37'},
#  'tracks': {'melody': [{'scale_degree': '3',
#     'octave': '0',
#     'isRest': False,
#     'event_on': 0.0,
#     'event_off': 16.0,
#     'event_duration': 16.0},
#    {'scale_degree': '6',
#     'octave': '-1',
#     'isRest': False,
#     'event_on': 16.0,
#     'event_off': 17.5,
#     'event_duration': 1.5},
#    {'scale_degree': '7',
#     'octave': '-1',
#     'isRest': False,
#     'event_on': 17.5,
#     'event_off': 19.0,
#     'event_duration': 1.5},
#    {'scale_degree': '1',
#     'octave': '0',
#     'isRest': False,
#     'event_on': 19.0,
#     'event_off': 28.0,
#     'event_duration': 9.0},
#    {'scale_degree': '7s',
#     'octave': '-1',
#     'isRest': False,
#     'event_on': 28.0,
#     'event_off': 32.0,
#     'event_duration': 4.0}],
#   'chord': [{'sd': '1',
# ...
